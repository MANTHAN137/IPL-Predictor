# %%
import numpy as np
import pandas as pd

# %%
match=pd.read_csv('Dataset/matches.csv')
delivery=pd.read_csv('Dataset/deliveries.csv')

# %%
match.shape
# Out:
# (756, 18)

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
TotalScore=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
TotalScore
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
TotalScore=TotalScore[TotalScore['inning']==1]
print(TotalScore)
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
 Match_Data=match.merge(TotalScore[['match_id','total_runs']],left_on='id',right_on='match_id')
 Match_Data
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
Match_Data['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
Match_Data['team1']=Match_Data['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
Match_Data['team2']=Match_Data['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

Match_Data['team1']=Match_Data['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
Match_Data['team2']=Match_Data['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

Match_Data['team1']=Match_Data['team1'].str.replace('Gujarat Lions','Gujarat Titans')
Match_Data['team2']=Match_Data['team1'].str.replace('Gujarat Lions','Gujarat Titans')

# %%
WorkingTeams=['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions', 'Royal Challengers Bangalore','Kolkata Knight Riders', 'Kings XI Punjab','Chennai Super Kings', 'Rajasthan Royals','Delhi Capitals']

# %%
Match_Data=Match_Data[Match_Data['team1'].isin(WorkingTeams)]
Match_Data['team1']=Match_Data['team2'].str.replace('Gujarat Lions','Gujarat Titans')
# Out:
# <ipython-input-310-c92f2b78f01a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Match_Data['team1']=Match_Data['team2'].str.replace('Gujarat Lions','Gujarat Titans')

# %%
Match_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 657 entries, 0 to 755
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               657 non-null    int64
#  1   Season           657 non-null    object
#  2   city             650 non-null    object
#  3   date             657 non-null    object
#  4   team1            657 non-null    object
#  5   team2            657 non-null    object
#  6   toss_winner      657 non-null    object
#  7   toss_decision    657 non-null    object
#  8   result           657 non-null    object
#  9   dl_applied       657 non-null    int64
#  10  winner           653 non-null    object
#  11  win_by_runs      657 non-null    int64
#  12  win_by_wickets   657 non-null    int64
#  13  player_of_match  653 non-null    object
#  14  venue            657 non-null    object
#  15  umpire1          655 non-null    object
#  16  umpire2          655 non-null    object
# ...

# %%
Match_Data['dl_applied'].value_counts()
# Out:
# 0    639
# 1     18
# Name: dl_applied, dtype: int64

# %%
Match_Data=Match_Data[Match_Data['dl_applied']==0]

# %%
Match_Data=Match_Data[['match_id','city','total_runs','winner']]
Match_Data
# Out:
#      match_id           city  total_runs                       winner
# 0           1      Hyderabad         207          Sunrisers Hyderabad
# 1           2           Pune         184       Rising Pune Supergiant
# 4           5      Bangalore         157  Royal Challengers Bangalore
# 6           7         Mumbai         178               Mumbai Indians
# 7           8         Indore         148              Kings XI Punjab
# ..        ...            ...         ...                          ...
# 751     11347         Mumbai         143               Mumbai Indians
# 752     11412        Chennai         136               Mumbai Indians
# 753     11413  Visakhapatnam         171               Delhi Capitals
# 754     11414  Visakhapatnam         155          Chennai Super Kings
# 755     11415      Hyderabad         152               Mumbai Indians
#
# [639 rows x 4 columns]

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
delivery=delivery[delivery['inning']==2]

# %%
Delivery_df=Match_Data.merge(delivery,on='match_id')

# %%
Delivery_df.shape
# Out:
# (73694, 24)

# %%
Delivery_df.head()
# Out:
#    match_id       city  total_runs_x               winner  inning  \
# 0         1  Hyderabad           207  Sunrisers Hyderabad       2
# 1         1  Hyderabad           207  Sunrisers Hyderabad       2
# 2         1  Hyderabad           207  Sunrisers Hyderabad       2
# 3         1  Hyderabad           207  Sunrisers Hyderabad       2
# 4         1  Hyderabad           207  Sunrisers Hyderabad       2
#
#                   batting_team         bowling_team  over  ball  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#          batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 0       CH Gayle  ...        0           0            0             0
# ...

# %%
Delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# 0          1
# 1          1
# 2          1
# 3          3
# 4          7
#         ...
# 73689    152
# 73690    154
# 73691    155
# 73692    157
# 73693    157
# Name: total_runs_y, Length: 73694, dtype: int64

# %%
Delivery_df['current_score']=Delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
Delivery_df['runs_left']=Delivery_df['total_runs_x']-Delivery_df['current_score']+1

# %%
Delivery_df.head()
# Out:
#    match_id       city  total_runs_x               winner  inning  \
# 0         1  Hyderabad           207  Sunrisers Hyderabad       2
# 1         1  Hyderabad           207  Sunrisers Hyderabad       2
# 2         1  Hyderabad           207  Sunrisers Hyderabad       2
# 3         1  Hyderabad           207  Sunrisers Hyderabad       2
# 4         1  Hyderabad           207  Sunrisers Hyderabad       2
#
#                   batting_team         bowling_team  over  ball  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#          batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 0       CH Gayle  ...           0            0             1           0
# ...

# %%
Delivery_df['balls_left']=126-(Delivery_df['over']*6+Delivery_df['ball'])

# %%
Delivery_df['balls_left']
# Out:
# 0        119
# 1        118
# 2        117
# 3        116
# 4        115
#         ...
# 73689      4
# 73690      3
# 73691      2
# 73692      1
# 73693      0
# Name: balls_left, Length: 73694, dtype: int64

# %%
Delivery_df['player_dismissed']=Delivery_df['player_dismissed'].fillna("0")
Delivery_df['player_dismissed']=Delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
Delivery_df['player_dismissed']=Delivery_df['player_dismissed'].astype('int')
wickets=Delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
Delivery_df['wickets']=10-wickets
Delivery_df.head()
# Out:
#    match_id       city  total_runs_x               winner  inning  \
# 0         1  Hyderabad           207  Sunrisers Hyderabad       2
# 1         1  Hyderabad           207  Sunrisers Hyderabad       2
# 2         1  Hyderabad           207  Sunrisers Hyderabad       2
# 3         1  Hyderabad           207  Sunrisers Hyderabad       2
# 4         1  Hyderabad           207  Sunrisers Hyderabad       2
#
#                   batting_team         bowling_team  over  ball  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#          batsman  ... batsman_runs extra_runs  total_runs_y  player_dismissed  \
# 0       CH Gayle  ...            1          0             1                 0
# ...

# %%
#Current Run rate
Delivery_df['crr']=(Delivery_df['current_score']*6)/(120-Delivery_df['balls_left'])

# %%
Delivery_df['rrr']=(Delivery_df['runs_left']*6)/(Delivery_df['balls_left'])

# %%
Delivery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73694 entries, 0 to 73693
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          73694 non-null  int64
#  1   city              72862 non-null  object
#  2   total_runs_x      73694 non-null  int64
#  3   winner            73667 non-null  object
#  4   inning            73694 non-null  int64
#  5   batting_team      73694 non-null  object
#  6   bowling_team      73694 non-null  object
#  7   over              73694 non-null  int64
#  8   ball              73694 non-null  int64
#  9   batsman           73694 non-null  object
#  10  non_striker       73694 non-null  object
#  11  bowler            73694 non-null  object
#  12  is_super_over     73694 non-null  int64
#  13  wide_runs         73694 non-null  int64
#  14  bye_runs          73694 non-null  int64
#  15  legbye_runs       73694 non-null  int64
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
Delivery_df['result']=Delivery_df.apply(result,axis=1)

# %%
Final_Dataframe=Delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
Final_Dataframe.head()
# Out:
#                   batting_team         bowling_team       city  runs_left  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        205
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        201
#
#    balls_left  wickets  total_runs_x  crr        rrr  result
# 0         119       10           207  6.0  10.436975       0
# 1         118       10           207  3.0  10.525424       0
# 2         117       10           207  2.0  10.615385       0
# 3         116       10           207  4.5  10.603448       0
# 4         115       10           207  8.4  10.486957       0

# %%
Final_Dataframe=Final_Dataframe.sample(Final_Dataframe.shape[0]) ##Shuffling to avoid bais outcomes

# %%
Final_Dataframe.head()
# Out:
#                       batting_team           bowling_team            city  \
# 4517                Mumbai Indians  Kolkata Knight Riders       Bangalore
# 13190  Royal Challengers Bangalore         Mumbai Indians  Port Elizabeth
# 55662                Gujarat Lions         Mumbai Indians          Mumbai
# 62918               Mumbai Indians    Chennai Super Kings            Pune
# 9812              Delhi Daredevils       Rajasthan Royals          Mumbai
#
#        runs_left  balls_left  wickets  total_runs_x       crr        rrr  \
# 4517          45          63        7           107  6.631579   4.285714
# 13190         53          24        4           157  6.562500  13.250000
# 55662        119          99        9           143  7.142857   7.212121
# 62918         77          47        9           176  8.219178   9.829787
# 9812         165          83        7           192  4.540541  11.927711
#
#        result
# 4517        1
# 13190       0
# 55662       1
# 62918       1
# ...

# %%
Final_Dataframe.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               5
# result            0
# dtype: int64

# %%
#Final_Dataframe=Final_Dataframe[Final_Dataframe['city'].notna()]
print(Final_Dataframe.shape)
Final_Dataframe=Final_Dataframe.dropna()
Final_Dataframe=Final_Dataframe[Final_Dataframe['balls_left']!=0]
# Out:
# (73694, 10)

# %%
Final_Dataframe.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
print(Final_Dataframe.shape)
# Out:
# (72611, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
x=Final_Dataframe.iloc[:,:-1]
y=Final_Dataframe.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
    
    ]
    ,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=
[
('step1',trf),
('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.810989464986573

# %%
pipe.predict_proba(x_test)[99]
# Out:
# array([0.28203504, 0.71796496])
